# %%
import pandas as pd

# Load dataset
df = pd.read_csv("rural_credit_dataset_mixed.csv")

print("Data Loaded Successfully!")
print("Shape:", df.shape)
print(df.head())
# Out:
# Data Loaded Successfully!
# Shape: (5000, 23)
#   borrower_id  age  gender education_level   village_state occupation_type  \
# 0       R0001   60    Male       Secondary     Maharashtra          Farmer
# 1       R0002   33    Male       Secondary          Odisha      Shopkeeper
# 2       R0003   20    Male         Primary  Madhya Pradesh           Dairy
# 3       R0004   42  Female         Primary           Bihar          Farmer
# 4       R0005   43    Male             NaN  Andhra Pradesh           Dairy
#
#    family_members  dependents  land_size_acres crop_type  ...  \
# 0               3           0             1.47     Wheat  ...
# 1               6           1             0.00       NaN  ...
# 2               3           0             0.00       NaN  ...
# 3               2           1             9.74   Millets  ...
# 4               3           1             0.00       NaN  ...
#
#    annual_yield_tonnes shop_monthly_revenue  business_expenses  \
# ...

# %%
# Drop ID columns (not useful for ML)
df = df.drop(columns=["borrower_id"])

# Replace missing/NA with 0 for numeric features
df = df.fillna(0)

# %%
X = df.drop(columns=["loan_repayment_status"])
y = df["loan_repayment_status"]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# Example: assume you already have your dataset loaded as X, y
# X = your features DataFrame
# y = your target column (e.g. loan_repayment)

# Define categorical columns
cat_cols = ["gender", "education_level", "village_state", "occupation_type", "irrigation_type", "crop_type"]

# Identify numeric columns automatically
num_cols = [col for col in X.columns if col not in cat_cols]

# --- STEP 1: Detect and fix mixed types in categorical columns ---
for col in cat_cols:
    # Check if column has mixed data types
    types = X[col].apply(type).value_counts()
    if len(types) > 1:
        print(f"⚠️ Column '{col}' has mixed types {list(types.index)}. Converting all to string.")
    X[col] = X[col].astype(str)

# --- STEP 2: Define column transformer ---
ct = ColumnTransformer([
    ("onehot", OneHotEncoder(drop="first", handle_unknown="ignore"), cat_cols)
], remainder="passthrough")

# --- STEP 3: Apply transformation ---
X_transformed = ct.fit_transform(X)

# --- STEP 4: Train-test split ---
X_train, X_test, y_train, y_test = train_test_split(
    X_transformed, y, test_size=0.2, random_state=42
)

# --- STEP 5: Output shapes ---
print("✅ Data Preprocessing Complete!")
print("Train Shape:", X_train.shape)
print("Test Shape:", X_test.shape)
# Out:
# ⚠️ Column 'education_level' has mixed types [<class 'str'>, <class 'int'>]. Converting all to string.
# ⚠️ Column 'irrigation_type' has mixed types [<class 'str'>, <class 'int'>]. Converting all to string.
# ⚠️ Column 'crop_type' has mixed types [<class 'str'>, <class 'int'>]. Converting all to string.
# ✅ Data Preprocessing Complete!
# Train Shape: (4000, 44)
# Test Shape: (1000, 44)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_mean=False)  # with_mean=False for sparse data from OneHotEncoder
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#logistic reg
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.812
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       529
#            1       0.84      0.74      0.79       471
#
#     accuracy                           0.81      1000
#    macro avg       0.82      0.81      0.81      1000
# weighted avg       0.81      0.81      0.81      1000

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=150, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.802

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=42)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)

print("XGBoost Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# XGBoost Accuracy: 0.806

# %%
# Get one-hot encoded column names
ohe_cols = ct.named_transformers_['onehot'].get_feature_names_out(cat_cols)

# Combine with numeric columns
all_feature_names = list(ohe_cols) + num_cols



X_train_df = pd.DataFrame(X_train, columns=all_feature_names)
X_test_df = pd.DataFrame(X_test, columns=all_feature_names)


#ohe_cols = ct.named_transformers_['onehot'].get_feature_names_out(cat_cols)
#shap.dependence_plot("onehot__crop_type_maize", shap_values.values[:, :, 1], X_test_df)

# %%
import shap
import matplotlib.pyplot as plt

# Use model.predict_proba to avoid XGBoost base_score bug
explainer = shap.Explainer(xgb_model.predict_proba, X_train_df)

# Compute SHAP values
shap_values = explainer(X_test_df)

# Summary plot for class 1
shap.summary_plot(shap_values.values[:, :, 1], X_test_df, feature_names=X_test_df.columns)

# Dependence plot for a specific feature
#shap.dependence_plot("crop_type", shap_values.values[:, :, 1], X_test_df, feature_names=X_test_df.columns)

# Force plot for the first test sample
# Out:
# PermutationExplainer explainer: 1001it [00:42, 18.05it/s]
# C:\Users\Lenovoideapad\AppData\Local\Temp\ipykernel_17864\2328034150.py:11: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values.values[:, :, 1], X_test_df, feature_names=X_test_df.columns)

# %%
import joblib

joblib.dump(xgb_model, "xgb_model.pkl")
joblib.dump(ct, "column_transformer.pkl")
joblib.dump(scaler, "scaler.pkl")
print("DONE")
